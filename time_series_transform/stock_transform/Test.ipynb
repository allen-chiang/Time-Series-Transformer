# %%
import stock_extractor as ys
client = ys.yahoo_stock("aapl")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-2fabbb7f9959> in <module>
# ----> 1 import stock_extractor as ys
#       2 client = ys.yahoo_stock("aapl")
#
# ~\Documents\Development\Time-Series-Transformer\time_series_transform\stock_transform\stock_extractor.py in <module>
#       1 import yfinance as yf
#       2 from datetime import datetime
# ----> 3 from time_series_transform.stock_transform.base import *
#       4
#       5
#
# ModuleNotFoundError: No module named 'time_series_transform'

# %%
info = client.getCompanyInfo()
print(info)
# Out:
# {'zip': '95014', 'sector': 'Technology', 'fullTimeEmployees': 137000, 'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides digital content stores and streaming services; AppleCare support services; and iCloud, a cloud service, which stores music, photos, contacts, calendars, mail, documents, and others. In addition, the company offers various service, such as Apple Arcade, a game subscription service; Apple Card, a co-branded credit card; Apple News+, a subscription news and magazine service; and Apple Pay, a cashless payment service, as well as licenses its intellectual property, and provides other related services. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store, Mac App Store, and Watch App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. has a collaboration with Google to develop COVID-19 tracking system for Android and iOS devices. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California.', 'city': 'Cupertino', 'phone': '408-996-1010', 'state': 'CA', 'country': 'United States', 'companyOfficers': [], 'website': 'http://www.apple.com', 'maxAge': 1, 'address1': 'One Apple Park Way', 'industry': 'Consumer Electronics', 'previousClose': 382.73, 'regularMarketOpen': 381.34, 'twoHundredDayAverage': 305.53976, 'trailingAnnualDividendYield': 0.0080474485, 'payoutRatio': 0.2408, 'volume24Hr': None, 'regularMarketDayHigh': 383.88, 'navPrice': None, 'averageDailyVolume10Day': 28249700, 'totalAssets': None, 'regularMarketPreviousClose': 382.73, 'fiftyDayAverage': 348.53302, 'trailingAnnualDividendRate': 3.08, 'open': 381.34, 'toCurrency': None, 'averageVolume10days': 28249700, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': 3.28, 'exDividendDate': 1588896000, 'beta': 1.182072, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 378.831, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 30.144564, 'regularMarketVolume': 21827181, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 1662995660800, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 35297252, 'priceToSalesTrailing12Months': None, 'dayLow': 378.831, 'ask': 383.9, 'ytdReturn': None, 'askSize': 800, 'volume': 21827181, 'fiftyTwoWeekHigh': 385.27, 'forwardPE': 25.837036, 'fromCurrency': None, 'fiveYearAvgDividendYield': 1.57, 'fiftyTwoWeekLow': 192.58, 'bid': 383.75, 'tradeable': False, 'dividendYield': 0.0086, 'bidSize': 900, 'dayHigh': 383.88, 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 6.298, 'beta3Year': None, 'profitMargins': 0.21350001, 'enterpriseToEbitda': 21.832, '52WeekChange': 0.86969435, 'morningStarRiskRating': None, 'forwardEps': 14.85, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 4334329856, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'bookValue': 18.137, 'sharesShort': 34828293, 'sharesPercentSharesOut': 0.008, 'fundFamily': None, 'lastFiscalYearEnd': 1569628800, 'heldPercentInstitutions': 0.62115, 'netIncomeToCommon': 57215000576, 'trailingEps': 12.728, 'lastDividendValue': None, 'SandP52WeekChange': 0.056643367, 'priceToBook': 21.154547, 'heldPercentInsiders': 0.00066, 'nextFiscalYearEnd': 1632787200, 'mostRecentQuarter': 1585353600, 'shortRatio': 1.09, 'sharesShortPreviousMonthDate': 15 ...

# %%
# plots
import matplotlib.pyplot as plt
# import seaborn
hist = client.getHistoricalByPeriod()

# %%
client.getNextEvent()
# Out:
#                                 Value
# Earnings Date     2020-07-30 00:00:00
# Earnings Average                 2.01
# Earnings Low                     1.55
# Earnings High                    2.47
# Revenue Average           51562800000
# Revenue Low               42799000000
# Revenue High              55838000000

# %%
hist.rolling(window=5).mean()

# %%
hist_ori = hist.reset_index()
hist_ori[['Date', 'Open', 'Close']].to_numpy()
# Out:
# array([[Timestamp('2020-06-08 00:00:00'), 330.25, 333.46],
#        [Timestamp('2020-06-09 00:00:00'), 332.14, 343.99],
#        [Timestamp('2020-06-10 00:00:00'), 347.9, 352.84],
#        [Timestamp('2020-06-11 00:00:00'), 349.31, 335.9],
#        [Timestamp('2020-06-12 00:00:00'), 344.72, 338.8],
#        [Timestamp('2020-06-15 00:00:00'), 333.25, 342.99],
#        [Timestamp('2020-06-16 00:00:00'), 351.46, 352.08],
#        [Timestamp('2020-06-17 00:00:00'), 355.15, 351.59],
#        [Timestamp('2020-06-18 00:00:00'), 351.41, 351.73],
#        [Timestamp('2020-06-19 00:00:00'), 354.64, 349.72],
#        [Timestamp('2020-06-22 00:00:00'), 351.34, 358.87],
#        [Timestamp('2020-06-23 00:00:00'), 364.0, 366.53],
#        [Timestamp('2020-06-24 00:00:00'), 365.0, 360.06],
#        [Timestamp('2020-06-25 00:00:00'), 360.7, 364.84],
#        [Timestamp('2020-06-26 00:00:00'), 364.41, 353.63],
#        [Timestamp('2020-06-29 00:00:00'), 353.25, 361.78],
#        [Timestamp('2020-06-30 00:00:00'), 360.08, 364.8],
#        [Timestamp('2020-07-01 00:00:00'), 365.12, 364.11],
#        [Timestamp('2020-07-02 00:00:00'), 367.85, 364.11],
#        [Timestamp('2020-07-06 00:00:00'), 370.0, 373.85],
#        [Timestamp('2020-07-07 00:00:00'), 375.41, 372.69]], dtype=object)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-0cc65bd144dc> in <module>
# ----> 1 hist.getActions
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'getActions'

# %%
hist['Close'].plot(figsize=(16,9))

# %%
from stock_transformer import Stock_Transformer, Standard_Indicator
import matplotlib.pyplot as plt
from scipy.fft import fft, ifft

# %%
st = Stock_Transformer("aapl")
st.get_company_info()
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 137000,
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides digital content stores and streaming services; AppleCare support services; and iCloud, a cloud service, which stores music, photos, contacts, calendars, mail, documents, and others. In addition, the company offers various service, such as Apple Arcade, a game subscription service; Apple Card, a co-branded credit card; Apple News+, a subscription news and magazine service; and Apple Pay, a cashless payment service, as well as licenses its intellectual property, and provides other related services. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store, Mac App Store, and Watch App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. has a collaboration with Google to develop COVID-19 tracking system for Android and iOS devices. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California.',
#  'city': 'Cupertino',
#  'phone': '408-996-1010',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.apple.com',
#  'maxAge': 1,
#  'address1': 'One Apple Park Way',
#  'industry': 'Consumer Electronics',
#  'previousClose': 381.37,
#  'regularMarketOpen': 385.05,
#  'twoHundredDayAverage': 304.65692,
#  'trailingAnnualDividendYield': 0.008076146000000001,
#  'payoutRatio': 0.24080000000000001,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 385.27,
#  'navPrice': None,
#  'averageDailyVolume10Day': 29950914,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 381.37,
#  'fiftyDayAverage': 345.6956,
#  'trailingAnnualDividendRate': 3.08,
#  'open': 385.05,
#  'toCurrency': None,
#  'averageVolume10days': 29950914,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': 3.2800000000000002,
#  'exDividendDate': 1588896000,
#  'beta': 1.182072,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 378.7,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 30.069925,
#  'regularMarketVolume': 30439246,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1658878164992,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 35503640,
#  'priceToSalesTrailing12Months': 6.190283,
#  'dayLow': 378.7,
#  'ask': 0,
#  'ytdReturn': None,
#  'askSize': 1200,
#  'volume': 30439246,
#  'fiftyTwoWeekHigh': 385.27,
#  'forwardPE': 25.773064,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.57,
#  'fiftyTwoWeekLow': 192.58,
#  'bid': 0,
#  'tradeable': False,
#  'dividendYield': 0.0086,
#  'bidSize': 800,
#  'dayHigh': 385.27,
#  'exchange': 'NMS',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'messageBoardId': 'finmb_24937',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 6.261,
#  'beta3Year': None,
#  'profitMargins': 0.21350001000000002,
#  'enterpriseToEbitda': 21.702,
#  '52WeekChange': 0.8839646600000001,
#  'morningStarRiskRating': None,
#  'forwardEps': 14.85,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 4334329856,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 18.137,
#  'sharesShort': 34828293,
#  'sharesPercentSharesOut': 0.008,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1569628800,
#  'heldPercentInstitutions': 0.6211500000000001,
#  'netIncomeToCommon': 57215000576,
#  'trailingEps': 12.728,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.045882702000000004,
#  'priceToBook': 21.102169,
#  'heldPercentInsiders': 0.0006600000000000001,
#  'nextFiscalYearEnd': 1632787200,
#  'mostRecentQuarter': 1585353600,
#  'shortRatio': 1.09,
#  'sharesShortPreviousMonthDate': 1589500800,
#  'floatShares': 4329740605,
#  'enterpriseValue': 1677695385600,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1402272000,
#  'lastSplitFactor': '7:1',
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': -0.027,
#  'dateShortInterest': 1592179200,
#  'pegRatio': 2.7,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.008,
#  'sharesShortPriorMonth': 33592445,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 385.05,
#  'logo_url': 'https://logo.clearbit.com/apple.com'}

# %%
df = st.get_stock_data_pandas()
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2019-07-10  199.47  201.33  199.18  200.83  17897100
# 2019-07-11  200.91  201.98  199.33  199.37  20191800
# 2019-07-12  200.06  201.59  199.82  200.90  17595200
# 2019-07-15  201.68  203.44  201.59  202.79  16947400
# 2019-07-16  202.18  203.68  201.10  202.09  16866800
# ...            ...     ...     ...     ...       ...
# 2020-07-02  367.85  370.47  363.64  364.11  28510400
# 2020-07-06  370.00  375.78  369.87  373.85  29663900
# 2020-07-07  375.41  378.62  372.23  372.69  28106100
# 2020-07-08  376.72  381.50  376.36  381.37  29273000
# 2020-07-09  385.05  385.27  378.69  383.01  31362900
#
# [253 rows x 5 columns]

# %%
plt.plot(df['Close'], label = "Close Price")
plt.show()

# %%
df.shape
# Out:
# (253, 5)

# %%
si = Standard_Indicator('aapl')
ma = si.moving_average(5)
ma2 = si.moving_average(2)

# %%
si.ma_plot([2,5,10])

# %%
plt.plot(ma['Close'], label = "Close Price")
plt.plot(ma2['Close'])
plt.legend(['12','34'])
plt.show()

# %%
xx = [1,2,3]
xxy = ["omfg " + str(x) for x in xx]
xxy
# Out:
# ['omfg 1', 'omfg 2', 'omfg 3']

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2019-07-10  199.47  201.33  199.18  200.83  17897100
# 2019-07-11  200.91  201.98  199.33  199.37  20191800
# 2019-07-12  200.06  201.59  199.82  200.90  17595200
# 2019-07-15  201.68  203.44  201.59  202.79  16947400
# 2019-07-16  202.18  203.68  201.10  202.09  16866800
# ...            ...     ...     ...     ...       ...
# 2020-07-02  367.85  370.47  363.64  364.11  28510400
# 2020-07-06  370.00  375.78  369.87  373.85  29663900
# 2020-07-07  375.41  378.62  372.23  372.69  28106100
# 2020-07-08  376.72  381.50  376.36  381.37  29273000
# 2020-07-09  385.05  385.27  378.69  383.01  31362900
#
# [253 rows x 5 columns]

# %%
df.ewm(alpha=0.9).mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2019-07-10  199.470000  201.330000  199.180000  200.830000  1.789710e+07
# 2019-07-11  200.779091  201.920909  199.316364  199.502727  1.998319e+07
# 2019-07-12  200.131261  201.622793  199.770090  200.761532  1.783185e+07
# 2019-07-15  201.525266  203.258443  201.408173  202.587336  1.703577e+07
# 2019-07-16  202.114532  203.637848  201.130815  202.139729  1.688369e+07
# ...                ...         ...         ...         ...           ...
# 2020-07-02  367.520853  370.141706  363.619401  364.113173  2.850082e+07
# 2020-07-06  369.752085  375.216171  369.244940  372.876317  2.954759e+07
# 2020-07-07  374.844209  378.279617  371.931494  372.708632  2.825025e+07
# 2020-07-08  376.532421  381.177962  375.917149  380.503863  2.917072e+07
# 2020-07-09  384.198242  384.860796  378.412715  382.759386  3.114368e+07
#
# [253 rows x 5 columns]

# %%
si.ema(0.9)
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2019-07-10  199.470000  201.330000  199.180000  200.830000  1.789710e+07
# 2019-07-11  200.779091  201.920909  199.316364  199.502727  1.998319e+07
# 2019-07-12  200.131261  201.622793  199.770090  200.761532  1.783185e+07
# 2019-07-15  201.525266  203.258443  201.408173  202.587336  1.703577e+07
# 2019-07-16  202.114532  203.637848  201.130815  202.139729  1.688369e+07
# ...                ...         ...         ...         ...           ...
# 2020-07-02  367.520853  370.141706  363.619401  364.113173  2.850082e+07
# 2020-07-06  369.752085  375.216171  369.244940  372.876317  2.954759e+07
# 2020-07-07  374.844209  378.279617  371.931494  372.708632  2.825025e+07
# 2020-07-08  376.532421  381.177962  375.917149  380.503863  2.917072e+07
# 2020-07-09  384.198242  384.860796  378.412715  382.759386  3.114368e+07
#
# [253 rows x 5 columns]

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 
#        -1.26113652e+02-2.34862274e+00j, -9.98958399e+01-8.43231750e+00j,
#        -3.82081708e+01+2.27025941e+01j, -8.45648562e+01+4.10809674e+01j,
#        -9.25894139e+01+3.32679054e+01j, -9.11426673e+01+1.53300560e+01j,
#        -1.14360647e+02+2.28326292e+01j, -1.15468143e+02+2.56346971e+00j,
#        -3.23369373e+01+3.99465337e+01j, -1.42802684e+02+4.41738458e+01j,
#        -7.18731395e+01-4.99972279e+01j, -2.30508072e+01+8.09195762e+01j,
#        -1.52756335e+02+5.02379467e+01j, -6.99395571e+01-8.60133937e+01j,
#         4.82138982e+01+5.43513384e+01j, -1.90976230e+02+1.19740477e+02j,
#        -1.67155154e+02-9.81812017e+01j, -1.52950052e+01+6.11654390e+01j,
#        -1.95461583e+02+1.28966119e+02j, -1.88227056e+02-4.68214770e+01j,
#        -5.96691450e+01-1.17889714e+01j, -9.62708811e+01+3.15149164e+01j,
#        -7.25317049e+01-2.22399010e+01j, -7.46590269e+01-1.16389878e+01j,
#        -6.67370380e+01+1.69920251e+01j, -1.07779178e+02-2.85083691e+01j,
#        -1.58843205e+01-4.85080047e+00j, -1.29456318e+02+2.37882941e+01j,
#        -5.71744719e+01-3.54502099e+01j, -2.90218118e+01-2.13154968e+01j,
#        -8.83842979e+01+1.22088119e+01j, -6.99440301e+01+8.38922902e+00j,
#        -9.84501278e+01+7.35389751e+00j])

# %%
df.shape
# Out:
# (253, 5)

# %%
from base import Stock,Portfolio
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from functools import reduce

# %%
df = pd.read_csv('../../Data/aapl_stock_extract.csv')
df2 = pd.read_csv('../../Data/googl_stock_extract.csv')

# %%
stock = Stock('aapl',df)
stock2 = Stock('googl',df2)

# %%
port = Portfolio([stock,stock2])

# %%
port.make_technical_indicator('High','mvg10','moving_average',1,50,windowSize = 10)
port.make_technical_indicator('High','fft','fast_fourier',1,50)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s finished

# %%
port.get_portfolio_dataFrame()
# Out:
#           Date     Open     High      Low    Close    Volume  Dividends  \
# 0   2020-06-11   349.31   351.06   335.48   335.90  50415600          0
# 1   2020-06-12   344.72   347.80   334.22   338.80  50001500          0
# 2   2020-06-15   333.25   345.68   332.58   342.99  34702200          0
# 3   2020-06-16   351.46   353.20   344.72   352.08  41357200          0
# 4   2020-06-17   355.15   355.40   351.09   351.59  28532000          0
# 5   2020-06-18   351.41   353.45   349.22   351.73  24205100          0
# 6   2020-06-19   354.64   356.56   345.15   349.72  66119000          0
# 7   2020-06-22   351.34   359.46   351.15   358.87  33861300          0
# 8   2020-06-23   364.00   372.38   362.27   366.53  53038900          0
# 9   2020-06-24   365.00   368.79   358.52   360.06  48155800          0
# 10  2020-06-25   360.70   365.00   357.57   364.84  34380600          0
# 11  2020-06-26   364.41   365.32   353.02   353.63  51314200          0
# 12  2020-06-29   353.25   362.17   351.28   361.78  32661500          0
# 13  2020-06-30   360.08   365.98   360.00   364.80  35055800          0
# 14  2020-07-01   365.12   367.36   363.91   364.11  27684300          0
# 15  2020-07-02   367.85   370.47   363.64   364.11  28510400          0
# 16  2020-07-06   370.00   375.78   369.87   373.85  29663900          0
# 17  2020-07-07   375.41   378.62   372.23   372.69  28106100          0
# 5              0         NaN    10.018062+90.725285j  googl
# 6              0         NaN   -23.114045+32.777150j  googl
# 7              0         NaN   -50.475000+41.751085j  googl
# 8              0         NaN   -29.666350-28.758812j  googl
# 9              0    1452.989   -68.857229+18.865231j  googl
# 10             0    1452.061   -35.524422-45.306158j  googl
# 11             0    1452.312   -35.524422+45.306158j  googl
# 12             0    1449.612   -68.857229-18.865231j  googl
# 13             0    1446.295   -29.666350+28.758812j  googl
# 14             0    1444.923   -50.475000-41.751085j  googl
# 15             0    1448.478   -23.114045-32.777150j  googl
# 16             0    1455.028    10.018062-90.725285j  googl
# 17             0    1462.065    4.891231-189.817475j  googl
# 18             0    1465.662   -70.023725+25.354793j  googl
# 19             0    1470.997 -120.257054-354.955702j  googl
# 20             0    1480.899  234.208533-215.686194j  googl

# %%
stockIndicators = {
    'aapl':['Close','mvg10_High'],
    'googl':['Open']
}
port.plot(stockIndicators,samePlot = True)

# %%
plt.plot(stock.df['Date'], stock.df['Open'],stock.df['Date'], stock.df['Close'], stock.df['Date'], stock2.df['Close'])
# stock.df['Open'].plot()
# Out:
# [<matplotlib.lines.Line2D at 0x1f163fb4188>,
#  <matplotlib.lines.Line2D at 0x1f163fb4d88>,
#  <matplotlib.lines.Line2D at 0x1f163fb4148>]

# %%
port.stockDict['aapl']

# %%
x = stock.df[['Date','Open']]
x['omg'] = stock.df['Close']
x
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Date    Open     omg
# 0   2020-06-11  349.31  335.90
# 1   2020-06-12  344.72  338.80
# 2   2020-06-15  333.25  342.99
# 3   2020-06-16  351.46  352.08
# 4   2020-06-17  355.15  351.59
# 5   2020-06-18  351.41  351.73
# 6   2020-06-19  354.64  349.72
# 7   2020-06-22  351.34  358.87
# 8   2020-06-23  364.00  366.53
# 9   2020-06-24  365.00  360.06
# 10  2020-06-25  360.70  364.84
# 11  2020-06-26  364.41  353.63
# 12  2020-06-29  353.25  361.78
# 13  2020-06-30  360.08  364.80
# 14  2020-07-01  365.12  364.11
# 15  2020-07-02  367.85  364.11
# 16  2020-07-06  370.00  373.85
# 17  2020-07-07  375.41  372.69
# 18  2020-07-08  376.72  381.37
# 19  2020-07-09  385.05  383.01
# 20  2020-07-10  381.34  383.68

# %%
x = stock.df[['Date','Close']].set_index('Date')
y = stock.df[['Date', 'Open']].set_index('Date')
w = stock2.df[['Date','High']].set_index('Date')
df = [x,y,w]

z = reduce(lambda  left,right: pd.merge(left,right,on=['Date'],
                                            how='outer'), df)
# z = pd.merge(x,y, left_on= 'Date',right_on='Date')
z
z.plot()

# %%
stockIndicators = {
    'aapl':['Close','mvg10_High'],
    'googl':['Open']
}

# for ix,i in enumerate(stockIndicators):
#     print(stockIndicators[i])
#     print(i)
x = port.stockDict['aapl'].df[stockIndicators['aapl']]
x.insert(0,"Date",port.stockDict['aapl'].df['Date'])

# %%
x.columns = [1,2,3]
x
# Out:
#              1       2        3
# 0   2020-06-11  335.90      NaN
# 1   2020-06-12  338.80      NaN
# 2   2020-06-15  342.99      NaN
# 3   2020-06-16  352.08      NaN
# 4   2020-06-17  351.59      NaN
# 5   2020-06-18  351.73      NaN
# 6   2020-06-19  349.72      NaN
# 7   2020-06-22  358.87      NaN
# 8   2020-06-23  366.53      NaN
# 9   2020-06-24  360.06  356.378
# 10  2020-06-25  364.84  357.772
# 11  2020-06-26  353.63  359.524
# 12  2020-06-29  361.78  361.173
# 13  2020-06-30  364.80  362.451
# 14  2020-07-01  364.11  363.647
# 15  2020-07-02  364.11  365.349
# 16  2020-07-06  373.85  367.271
# 17  2020-07-07  372.69  369.187
# 18  2020-07-08  381.37  370.099
# 19  2020-07-09  383.01  371.747
# 20  2020-07-10  383.68  373.639

# %%
stock2.make_technical_indicator('Close','movg10','moving_average',windowSize = 10).plot('Close')

# %%
import yfinance as yf
class yahoo_stock(object):

    """
    Fetching stock data from yahoo finance
    
    API Document: 
    - https://github.com/ranaroussi/yfinance
    - https://pypi.org/project/fix-yahoo-finance/0.1.0/
    ---
    Require:
    - yfinance

    """
    def __init__(self,symbol):
        self._symbol = symbol
        self._ticker = self._getStock(symbol)
    

    # getter and setter
    @property
    def ticker(self):
        return self._ticker

    @property
    def symbol(self):
        return self._symbol

    @symbol.setter
    def symbol(self, symbol):
        self._symbol = symbol
        self._ticker = yf.Ticker(symbol)
    
    def _getStock(self, symbol):
        ticker = yf.Ticker(symbol)
        return ticker

    def getCompanyInfo(self):
        return self.ticker.info

    """
    Historical Data
    ---
    Input:
    symbol: string
    period: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
    (default is '1mo')
    start_date, end_date: String, "%Y-%m-%d", eg "2020-02-20"
    ---
    Return:
    date, open, high, low, close, volume, dividends, stock splits
    """

    def getHistoricalByPeriod(self, period = '1mo'):
        return self.ticker.history(period)

    def getHistoricalByRange(self, start_date, end_date):
        return self.ticker.history(start = start_date, end = end_date)

    def getActions(self):
        return self.ticker.actions

    def getDividends(self):
        return self.ticker.dividends

    def getSplits(self):
        return self.ticker.splits

    def getSustainability(self):
        return self.ticker.sustainability

    def getRecommendations(self):
        return self.ticker.recommendations

    def getNextEvent(self):
        return self.ticker.calendar

    def getCashFlow(self):
        return self.ticker.cashflow

    def getAdditionalInfo(self):
        pass

# %%
client = yf.Ticker("aapl")
client.history('12min')
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2020-07-13  389.06  399.82  381.03  381.91  47820100          0             0
# 2020-07-13  389.06  399.82  381.04  381.91  47912285          0             0

# %%
client = yahoo_stock("aapl")

# %%
data = client.getHistoricalByPeriod()

# %%
st = Stock('aapl', data)

# %%
st.save("C:/Users/User/Documents/Development/Time-Series-Transformer/Data")

# %%
port = Portfolio([st,googl])

# %%
sustainability = client.getSustainability()

# %%
recommendations = client.getRecommendations()

# %%
nextEvent = client.getNextEvent()

# %%
client.getCashFlow()
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
x= {
    'info' : info,
    'actions' : actions
}

# %%
recommendations
# Out:
#                                   Firm    To Grade From Grade Action
# Date
# 2012-02-09 08:17:00  Canaccord Genuity         Buy              main
# 2012-03-08 07:33:00     FBN Securities  Outperform              main
# 2012-03-13 06:08:00          Jefferies         Buy              main
# 2012-03-14 06:13:00     Morgan Stanley  Overweight              main
# 2012-03-14 08:21:00  Canaccord Genuity         Buy              main
# ...                                ...         ...        ...    ...
# 2020-06-23 15:49:39      Deutsche Bank         Buy              main
# 2020-06-23 15:51:49                UBS         Buy              main
# 2020-06-25 09:00:31            Wedbush  Outperform              main
# 2020-07-07 11:42:52      Raymond James  Outperform              reit
# 2020-07-07 15:04:24            Cascend         Buy              main
#
# [715 rows x 4 columns]

# %%
nextEvent
# Out:
#                                 Value
# Earnings Date     2020-07-30 00:00:00
# Earnings Average                 2.01
# Earnings Low                     1.55
# Earnings High                    2.47
# Revenue Average           51474300000
# Revenue Low               42799000000
# Revenue High              55838000000

# %%
actions
# Out:
#             Dividends  Stock Splits
# Date
# 1987-05-11    0.00214           0.0
# 1987-06-16    0.00000           2.0
# 1987-08-10    0.00214           0.0
# 1987-11-17    0.00286           0.0
# 1988-02-12    0.00286           0.0
# ...               ...           ...
# 2019-05-10    0.77000           0.0
# 2019-08-09    0.77000           0.0
# 2019-11-07    0.77000           0.0
# 2020-02-07    0.77000           0.0
# 2020-05-08    0.82000           0.0
#
# [71 rows x 2 columns]

# %%
type(info)
# Out:
# dict

# %%
sustainability
# Out:
#                                      Value
# 2020-7
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                          12.98
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                         0
# peerCount                               57
# governanceScore                      10.15
# environmentPercentile                    0
# animalTesting                        False
# tobacco                              False
# totalEsg                             23.62
# highestControversy                       3
# esgPerformance                    AVG_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# percentile                           33.02
# peerGroup              Technology Hardware
# smallArms                            False
# environmentScore                      0.49
# governancePercentile                     0
# militaryContract                     False

# %%
pd_dict = pd.DataFrame.from_dict(info, orient='index', columns = ['Value'])
pd_dict
# Out:
#                                                                    Value
# zip                                                                95014
# sector                                                        Technology
# fullTimeEmployees                                                 137000
# longBusinessSummary    Apple Inc. designs, manufactures, and markets ...
# city                                                           Cupertino
# ...                                                                  ...
# sharesShortPriorMonth                                           33592445
# category                                                            None
# fiveYearAverageReturn                                               None
# regularMarketPrice                                                381.34
# logo_url                             https://logo.clearbit.com/apple.com
#
# [121 rows x 1 columns]

# %%
ax = st.df['Open','Close'].plot()
# googl.df['Open'].plot(ax = ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-95c2f7d8e19b> in <module>
# ----> 1 ax = st.df['Open','Close'].plot()
#       2 # googl.df['Open'].plot(ax = ax)
#
# NameError: name 'st' is not defined

# %%
googl.df['Open'].plot(ax=ax)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(5)
y = np.exp(x)
fig1, ax1 = plt.subplots()
ax1.plot(x, y)
ax1.set_title("Axis 1 title")
ax1.set_xlabel("X-label for axis 1")

z = np.sin(x)
fig2, (ax2, ax3) = plt.subplots(nrows=2, ncols=1) # two axes on figure
ax2.plot(x, z)
ax3.plot(x, -z)

w = np.cos(x)
ax1.plot(x, w) # can continue plotting on the first axis

# %%
x = np.arange(5)
y = np.exp(x)
fig1, ax1 = plt.subplots()
ax1.plot(x, y)
ax1.set_title("Axis 1 title")
ax1.set_xlabel("X-label for axis 1")
# Out:
# Text(0.5, 0, 'X-label for axis 1')

# %%
df = st.df['Open']
df2 = googl.df['Open']

# %%
fig1, ax1 = plt.subplots()
ax1.plot(df)
ax1.plot(df2)

# %%
plt.show()
