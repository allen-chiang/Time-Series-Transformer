# %%
import ystock as ys
client = ys.ystock("aapl")

# %%
info = client.getCompanyInfo()
print(info)
# Out:
# {'zip': '95014', 'sector': 'Technology', 'fullTimeEmployees': 137000, 'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides digital content stores and streaming services; AppleCare support services; and iCloud, a cloud service, which stores music, photos, contacts, calendars, mail, documents, and others. In addition, the company offers various service, such as Apple Arcade, a game subscription service; Apple Card, a co-branded credit card; Apple News+, a subscription news and magazine service; and Apple Pay, a cashless payment service, as well as licenses its intellectual property, and provides other related services. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store, Mac App Store, and Watch App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. has a collaboration with Google to develop COVID-19 tracking system for Android and iOS devices. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California.', 'city': 'Cupertino', 'phone': '408-996-1010', 'state': 'CA', 'country': 'United States', 'companyOfficers': [], 'website': 'http://www.apple.com', 'maxAge': 1, 'address1': 'One Apple Park Way', 'industry': 'Consumer Electronics', 'previousClose': 373.85, 'regularMarketOpen': 375.41, 'twoHundredDayAverage': 302.81757, 'trailingAnnualDividendYield': 0.008238598, 'payoutRatio': 0.2408, 'volume24Hr': None, 'regularMarketDayHigh': 378.62, 'navPrice': None, 'averageDailyVolume10Day': 30715180, 'totalAssets': None, 'regularMarketPreviousClose': 373.85, 'fiftyDayAverage': 340.115, 'trailingAnnualDividendRate': 3.08, 'open': 375.41, 'toCurrency': None, 'averageVolume10days': 30715180, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': 3.28, 'exDividendDate': 1588896000, 'beta': 1.182072, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 372.23, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 29.281113, 'regularMarketVolume': 28106114, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 1615361343488, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 36225135, 'priceToSalesTrailing12Months': 6.027895, 'dayLow': 372.23, 'ask': 374.91, 'ytdReturn': None, 'askSize': 1800, 'volume': 28106114, 'fiftyTwoWeekHigh': 378.62, 'forwardPE': 25.09697, 'fromCurrency': None, 'fiveYearAvgDividendYield': 1.57, 'fiftyTwoWeekLow': 192.58, 'bid': 374.85, 'tradeable': False, 'dividendYield': 0.0088, 'bidSize': 900, 'dayHigh': 378.62, 'exchange': 'NMS', 'shortName': 'Apple Inc.', 'longName': 'Apple Inc.', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'EQUITY', 'symbol': 'AAPL', 'messageBoardId': 'finmb_24937', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 6.12, 'beta3Year': None, 'profitMargins': 0.21350001, 'enterpriseToEbitda': 21.216, '52WeekChange': 0.85773206, 'morningStarRiskRating': None, 'forwardEps': 14.85, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 4334329856, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'bookValue': 18.137, 'sharesShort': 34828293, 'sharesPercentSharesOut': 0.008, 'fundFamily': None, 'lastFiscalYearEnd': 1569628800, 'heldPercentInstituti ...

# %%
# plots
import matplotlib.pyplot as plt
# import seaborn
hist = client.getHistoricalByPeriod()

# %%
hist.rolling(window=5).mean()
# Out:
#                Open     High      Low    Close      Volume  Dividends  \
# Date
# 2020-06-08      NaN      NaN      NaN      NaN         NaN        NaN
# 2020-06-09      NaN      NaN      NaN      NaN         NaN        NaN
# 2020-06-10      NaN      NaN      NaN      NaN         NaN        NaN
# 2020-06-11      NaN      NaN      NaN      NaN         NaN        NaN
# 2020-06-12  340.864  346.568  335.024  340.998  40584340.0        0.0
# 2020-06-15  341.464  348.984  336.076  342.904  42742060.0        0.0
# 2020-06-16  345.328  350.502  338.618  344.522  43627880.0        0.0
# 2020-06-17  346.778  350.628  339.618  344.272  41001700.0        0.0
# 2020-06-18  347.198  351.106  342.366  347.438  35759600.0        0.0
# 2020-06-19  349.182  352.858  344.552  349.622  38983100.0        0.0
# 2020-06-22  352.800  355.614  348.266  352.798  38814920.0        0.0
# 2020-06-23  355.308  359.450  351.776  355.688  41151260.0        0.0
# 2020-06-24  357.278  362.128  353.262  357.382  45076020.0        0.0
# 2020-06-25  359.136  364.438  354.932  360.004  47111120.0        0.0
# 2020-06-26  361.090  366.190  356.506  360.786  44150160.0        0.0
# 2020-06-29  361.472  366.732  356.532  361.368  43910200.0        0.0
# 2020-06-30  360.688  365.452  356.078  361.022  40313580.0        0.0
# 2020-07-01  360.712  365.166  357.156  361.832  36219280.0        0.0
# 2020-07-02  362.142  366.260  358.370  361.686  35045240.0        0.0
# 2020-07-06  363.260  368.352  361.740  365.730  30715180.0        0.0
# 2020-07-07  367.692  371.642  365.930  367.912  29794860.0        0.0
#
#             Stock Splits
# Date
# 2020-06-08           NaN
# 2020-06-09           NaN
# 2020-06-10           NaN
# 2020-06-11           NaN
# 2020-06-12           0.0
# 2020-06-15           0.0
# 2020-06-16           0.0
# 2020-06-17           0.0
# 2020-06-18           0.0
# 2020-06-19           0.0
# 2020-06-22           0.0
# 2020-06-23           0.0
# 2020-06-24           0.0
# 2020-06-25           0.0
# 2020-06-26           0.0
# 2020-06-29           0.0
# 2020-06-30           0.0
# 2020-07-01           0.0
# 2020-07-02           0.0
# 2020-07-06           0.0
# 2020-07-07           0.0

# %%
hist_ori = hist.reset_index()
hist_ori[['Date', 'Open', 'Close']].to_numpy()
# Out:
# array([[Timestamp('2020-06-08 00:00:00'), 330.25, 333.46],
#        [Timestamp('2020-06-09 00:00:00'), 332.14, 343.99],
#        [Timestamp('2020-06-10 00:00:00'), 347.9, 352.84],
#        [Timestamp('2020-06-11 00:00:00'), 349.31, 335.9],
#        [Timestamp('2020-06-12 00:00:00'), 344.72, 338.8],
#        [Timestamp('2020-06-15 00:00:00'), 333.25, 342.99],
#        [Timestamp('2020-06-16 00:00:00'), 351.46, 352.08],
#        [Timestamp('2020-06-17 00:00:00'), 355.15, 351.59],
#        [Timestamp('2020-06-18 00:00:00'), 351.41, 351.73],
#        [Timestamp('2020-06-19 00:00:00'), 354.64, 349.72],
#        [Timestamp('2020-06-22 00:00:00'), 351.34, 358.87],
#        [Timestamp('2020-06-23 00:00:00'), 364.0, 366.53],
#        [Timestamp('2020-06-24 00:00:00'), 365.0, 360.06],
#        [Timestamp('2020-06-25 00:00:00'), 360.7, 364.84],
#        [Timestamp('2020-06-26 00:00:00'), 364.41, 353.63],
#        [Timestamp('2020-06-29 00:00:00'), 353.25, 361.78],
#        [Timestamp('2020-06-30 00:00:00'), 360.08, 364.8],
#        [Timestamp('2020-07-01 00:00:00'), 365.12, 364.11],
#        [Timestamp('2020-07-02 00:00:00'), 367.85, 364.11],
#        [Timestamp('2020-07-06 00:00:00'), 370.0, 373.85],
#        [Timestamp('2020-07-07 00:00:00'), 375.41, 372.69]], dtype=object)

# %%
hist
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2020-06-08  330.25  333.60  327.32  333.46  23913600          0             0
# 2020-06-09  332.14  345.61  332.01  343.99  36928100          0             0
# 2020-06-10  347.90  354.77  346.09  352.84  41662900          0             0
# 2020-06-11  349.31  351.06  335.48  335.90  50415600          0             0
# 2020-06-12  344.72  347.80  334.22  338.80  50001500          0             0
# 2020-06-15  333.25  345.68  332.58  342.99  34702200          0             0
# 2020-06-16  351.46  353.20  344.72  352.08  41357200          0             0
# 2020-06-17  355.15  355.40  351.09  351.59  28532000          0             0
# 2020-06-18  351.41  353.45  349.22  351.73  24205100          0             0
# 2020-06-19  354.64  356.56  345.15  349.72  66119000          0             0
# 2020-06-22  351.34  359.46  351.15  358.87  33861300          0             0
# 2020-06-23  364.00  372.38  362.27  366.53  53038900          0             0
# 2020-06-24  365.00  368.79  358.52  360.06  48155800          0             0
# 2020-06-25  360.70  365.00  357.57  364.84  34380600          0             0
# 2020-06-26  364.41  365.32  353.02  353.63  51314200          0             0
# 2020-06-29  353.25  362.17  351.28  361.78  32661500          0             0
# 2020-06-30  360.08  365.98  360.00  364.80  35055800          0             0
# 2020-07-01  365.12  367.36  363.91  364.11  27684300          0             0
# 2020-07-02  367.85  370.47  363.64  364.11  28510400          0             0
# 2020-07-06  370.00  375.78  369.87  373.85  29663900          0             0
# 2020-07-07  375.41  378.62  372.23  372.69  28059900          0             0

# %%
hist['Close'].plot(figsize=(16,9))

# %%
from stock_transformer import Stock_Transformer, Standard_Indicator

# %%
st = Stock_Transformer("aapl")
st.get_company_info()
# Out:
# {'52WeekChange': 0.8338337,
#  'SandP52WeekChange': 0.050867558,
#  'address1': 'One Apple Park Way',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 0,
#  'askSize': 1800,
#  'averageDailyVolume10Day': 30272633,
#  'averageVolume': 35858319,
#  'averageVolume10days': 30272633,
#  'beta': 1.182072,
#  'beta3Year': None,
#  'bid': 0,
#  'bidSize': 900,
#  'bookValue': 18.137,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Cupertino',
#  'companyOfficers': [],
#  'country': 'United States',
#  'currency': 'USD',
#  'dateShortInterest': 1592179200,
#  'dayHigh': 381.47,
#  'dayLow': 376.36,
#  'dividendRate': 3.28,
#  'dividendYield': 0.0088,
#  'earningsQuarterlyGrowth': -0.027,
#  'enterpriseToEbitda': 21.216,
#  'enterpriseToRevenue': 6.12,
#  'enterpriseValue': 1640073265152,
#  'exDividendDate': 1588896000,
#  'exchange': 'NMS',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'expireDate': None,
#  'fiftyDayAverage': 341.81293,
#  'fiftyTwoWeekHigh': 381.47,
#  'fiftyTwoWeekLow': 192.58,
#  'fiveYearAverageReturn': None,
#  'fiveYearAvgDividendYield': 1.57,
#  'floatShares': 4329740605,
#  'forwardEps': 14.85,
#  'forwardPE': 25.68148,
#  'fromCurrency': None,
#  'fullTimeEmployees': 137000,
#  'fundFamily': None,
#  'fundInceptionDate': None,
#  'gmtOffSetMilliseconds': '-14400000',
#  'heldPercentInsiders': 0.00066,
#  'heldPercentInstitutions': 0.62115,
#  'industry': 'Consumer Electronics',
#  'isEsgPopulated': False,
#  'lastCapGain': None,
#  'lastDividendValue': None,
#  'lastFiscalYearEnd': 1569628800,
#  'lastMarket': None,
#  'lastSplitDate': 1402272000,
#  'lastSplitFactor': '7:1',
#  'legalType': None,
#  'logo_url': 'https://logo.clearbit.com/apple.com',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides digital content stores and streaming services; AppleCare support services; and iCloud, a cloud service, which stores music, photos, contacts, calendars, mail, documents, and others. In addition, the company offers various service, such as Apple Arcade, a game subscription service; Apple Card, a co-branded credit card; Apple News+, a subscription news and magazine service; and Apple Pay, a cashless payment service, as well as licenses its intellectual property, and provides other related services. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store, Mac App Store, and Watch App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. has a collaboration with Google to develop COVID-19 tracking system for Android and iOS devices. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California.',
#  'longName': 'Apple Inc.',
#  'market': 'us_market',
#  'marketCap': 1652983332864,
#  'maxAge': 1,
#  'maxSupply': None,
#  'messageBoardId': 'finmb_24937',
#  'morningStarOverallRating': None,
#  'morningStarRiskRating': None,
#  'mostRecentQuarter': 1585353600,
#  'navPrice': None,
#  'netIncomeToCommon': 57215000576,
#  'nextFiscalYearEnd': 1632787200,
#  'open': 376.72,
#  'openInterest': None,
#  'payoutRatio': 0.2408,
#  'pegRatio': 2.63,
#  'phone': '408-996-1010',
#  'previousClose': 372.69,
#  'priceHint': 2,
#  'priceToBook': 21.027184,
#  'priceToSalesTrailing12Months': 6.168286,
#  'profitMargins': 0.21350001,
#  'quoteType': 'EQUITY',
#  'regularMarketDayHigh': 381.47,
#  'regularMarketDayLow': 376.36,
#  'regularMarketOpen': 376.72,
#  'regularMarketPreviousClose': 372.69,
#  'regularMarketPrice': 376.72,
#  'regularMarketVolume': 29272970,
#  'revenueQuarterlyGrowth': None,
#  'sector': 'Technology',
#  'sharesOutstanding': 4334329856,
#  'sharesPercentSharesOut': 0.008,
#  'sharesShort': 34828293,
#  'sharesShortPreviousMonthDate': 1589500800,
#  'sharesShortPriorMonth': 33592445,
#  'shortName': 'Apple Inc.',
#  'shortPercentOfFloat': 0.008,
#  'shortRatio': 1.09,
#  'startDate': None,
#  'state': 'CA',
#  'strikePrice': None,
#  'symbol': 'AAPL',
#  'threeYearAverageReturn': None,
#  'toCurrency': None,
#  'totalAssets': None,
#  'tradeable': False,
#  'trailingAnnualDividendRate': 3.08,
#  'trailingAnnualDividendYield': 0.008264241,
#  'trailingEps': 12.728,
#  'trailingPE': 29.963074,
#  'twoHundredDayAverage': 303.5083,
#  'volume': 29272970,
#  'volume24Hr': None,
#  'volumeAllCurrencies': None,
#  'website': 'http://www.apple.com',
#  'yield': None,
#  'ytdReturn': None,
#  'zip': '95014'}

# %%
df = st.get_stock_data_pandas()
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2019-07-09  196.85  199.13  196.47  198.87  20578000
# 2019-07-10  199.47  201.33  199.18  200.83  17897100
# 2019-07-11  200.91  201.98  199.33  199.37  20191800
# 2019-07-12  200.06  201.59  199.82  200.90  17595200
# 2019-07-15  201.68  203.44  201.59  202.79  16947400
# ...            ...     ...     ...     ...       ...
# 2020-07-01  365.12  367.36  363.91  364.11  27684300
# 2020-07-02  367.85  370.47  363.64  364.11  28510400
# 2020-07-06  370.00  375.78  369.87  373.85  29663900
# 2020-07-07  375.41  378.62  372.23  372.69  28106100
# 2020-07-08  376.72  381.50  376.36  381.37  29158300
#
# [253 rows x 5 columns]

# %%
plt.plot(df['Close'], label = "Close Price")
plt.show()

# %%
df.shape
# Out:
# (253, 5)

# %%
si = Standard_Indicator('aapl')
ma = si.moving_average(5)
ma2 = si.moving_average(2)

# %%
si.ma_plot([2,5,10])

# %%
import matplotlib.pyplot as plt
plt.plot(ma['Close'], label = "Close Price")
plt.plot(ma2['Close'])
plt.legend(['12','34'])
plt.show()

# %%
xx = [1,2,3]
xxy = ["omfg " + str(x) for x in xx]
xxy
# Out:
# ['omfg 1', 'omfg 2', 'omfg 3']
